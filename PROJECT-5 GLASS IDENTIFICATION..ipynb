# %% [markdown]
# # Glass Identification

# %% [markdown]
# # Project Description
# The dataset describes the chemical properties of glass and involves classifying samples of glass using their chemical properties as one of six classes. The dataset was credited to Vina Spiehler in 1987. The study of classification of types of glass was motivated by criminological investigation. At the scene of the crime, the glass left can be used as evidence...if it is correctly identified!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\KARTIK NEGI\Desktop\glass.csv")
df.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
df.columns.tolist()
# Out:
# ['1',
#  '1.52101',
#  '13.64',
#  '4.49',
#  '1.10',
#  '71.78',
#  '0.06',
#  '8.75',
#  '0.00',
#  '0.00.1',
#  '1.1']

# %%
df.shape
# Out:
# (213, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1        213 non-null    int64
#  1   1.52101  213 non-null    float64
#  2   13.64    213 non-null    float64
#  3   4.49     213 non-null    float64
#  4   1.10     213 non-null    float64
#  5   71.78    213 non-null    float64
#  6   0.06     213 non-null    float64
#  7   8.75     213 non-null    float64
#  8   0.00     213 non-null    float64
#  9   0.00.1   213 non-null    float64
#  10  1.1      213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %%
df.tail()
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 208  210  1.51623  14.14   0.0  2.88  72.61  0.08  9.18  1.06     0.0    7
# 209  211  1.51685  14.92   0.0  1.99  73.06  0.00  8.40  1.59     0.0    7
# 210  212  1.52065  14.36   0.0  2.02  73.42  0.00  8.44  1.64     0.0    7
# 211  213  1.51651  14.38   0.0  1.94  73.61  0.00  8.48  1.57     0.0    7
# 212  214  1.51711  14.23   0.0  2.08  73.36  0.00  8.62  1.67     0.0    7

# %%
df.describe()
# Out:
#                 1     1.52101       13.64        4.49        1.10       71.78  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean   108.000000    1.518353   13.406761    2.676056    1.446526   72.655023
# std     61.631972    0.003039    0.818371    1.440453    0.499882    0.774052
# min      2.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     55.000000    1.516520   12.900000    2.090000    1.190000   72.280000
# 50%    108.000000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    161.000000    1.519150   13.830000    3.600000    1.630000   73.090000
# max    214.000000    1.533930   17.380000    3.980000    3.500000   75.410000
#
#              0.06        8.75        0.00      0.00.1         1.1
# count  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     0.499108    8.957934    0.175869    0.057277    2.788732
# std      0.653035    1.426435    0.498245    0.097589    2.105130
# ...

# %%
df.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %%
df.columns=['Id number','RI','Sodium','Magnesium','Aluminum','Silicon','Potassium','Calcium','Barium','Iron','Type of glass']
df
# Out:
#      Id number       RI  Sodium  Magnesium  Aluminum  Silicon  Potassium  \
# 0            2  1.51761   13.89       3.60      1.36    72.73       0.48
# 1            3  1.51618   13.53       3.55      1.54    72.99       0.39
# 2            4  1.51766   13.21       3.69      1.29    72.61       0.57
# 3            5  1.51742   13.27       3.62      1.24    73.08       0.55
# 4            6  1.51596   12.79       3.61      1.62    72.97       0.64
# ..         ...      ...     ...        ...       ...      ...        ...
# 208        210  1.51623   14.14       0.00      2.88    72.61       0.08
# 209        211  1.51685   14.92       0.00      1.99    73.06       0.00
# 210        212  1.52065   14.36       0.00      2.02    73.42       0.00
# 211        213  1.51651   14.38       0.00      1.94    73.61       0.00
# 212        214  1.51711   14.23       0.00      2.08    73.36       0.00
#
#      Calcium  Barium  Iron  Type of glass
# 0       7.83    0.00  0.00              1
# ...

# %%
df.describe()
# Out:
#         Id number          RI      Sodium   Magnesium    Aluminum     Silicon  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean   108.000000    1.518353   13.406761    2.676056    1.446526   72.655023
# std     61.631972    0.003039    0.818371    1.440453    0.499882    0.774052
# min      2.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     55.000000    1.516520   12.900000    2.090000    1.190000   72.280000
# 50%    108.000000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    161.000000    1.519150   13.830000    3.600000    1.630000   73.090000
# max    214.000000    1.533930   17.380000    3.980000    3.500000   75.410000
#
#         Potassium     Calcium      Barium        Iron  Type of glass
# count  213.000000  213.000000  213.000000  213.000000     213.000000
# mean     0.499108    8.957934    0.175869    0.057277       2.788732
# ...

# %%
df.nunique()
# Out:
# Id number        213
# RI               177
# Sodium           142
# Magnesium         93
# Aluminum         117
# Silicon          132
# Potassium         65
# Calcium          143
# Barium            34
# Iron              32
# Type of glass      6
# dtype: int64

# %%
df.drop('Id number', axis=1, inplace=True)

# %%
df
# Out:
#           RI  Sodium  Magnesium  Aluminum  Silicon  Potassium  Calcium  \
# 0    1.51761   13.89       3.60      1.36    72.73       0.48     7.83
# 1    1.51618   13.53       3.55      1.54    72.99       0.39     7.78
# 2    1.51766   13.21       3.69      1.29    72.61       0.57     8.22
# 3    1.51742   13.27       3.62      1.24    73.08       0.55     8.07
# 4    1.51596   12.79       3.61      1.62    72.97       0.64     8.07
# ..       ...     ...        ...       ...      ...        ...      ...
# 208  1.51623   14.14       0.00      2.88    72.61       0.08     9.18
# 209  1.51685   14.92       0.00      1.99    73.06       0.00     8.40
# 210  1.52065   14.36       0.00      2.02    73.42       0.00     8.44
# 211  1.51651   14.38       0.00      1.94    73.61       0.00     8.48
# 212  1.51711   14.23       0.00      2.08    73.36       0.00     8.62
#
#      Barium  Iron  Type of glass
# 0      0.00  0.00              1
# 1      0.00  0.00              1
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
sns.barplot(x="Type of glass",y="Sodium",data=df)
plt.show()

# %%
sns.barplot(x="Type of glass",y="Aluminum",data=df)
plt.show()

# %%
sns.barplot(x="Type of glass",y="Silicon",data=df,hue="Type of glass")
plt.show()

# %%
sns.barplot(x="Type of glass",y="RI",data=df,hue="Type of glass")
plt.show()

# %%
sns.barplot(x="Type of glass",y="Magnesium",data=df,hue="Type of glass")
plt.show()

# %%
sns.barplot(x="Type of glass",y="Calcium",data=df,hue="Type of glass")
plt.show()

# %%
sns.barplot(x="Type of glass",y="Barium",data=df,hue="Type of glass")
plt.show()

# %%
sns.barplot(x="Type of glass",y="Iron",data=df,hue="Type of glass")
plt.show()

# %%
df.describe()
# Out:
#                RI      Sodium   Magnesium    Aluminum     Silicon   Potassium  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#           Calcium      Barium        Iron  Type of glass
# count  213.000000  213.000000  213.000000     213.000000
# mean     8.957934    0.175869    0.057277       2.788732
# std      1.426435    0.498245    0.097589       2.105130
# ...

# %%
df.skew()
# Out:
# RI               1.639658
# Sodium           0.457318
# Magnesium       -1.154323
# Aluminum         0.900017
# Silicon         -0.744546
# Potassium        6.549276
# Calcium          2.040591
# Barium           3.406749
# Iron             1.747173
# Type of glass    1.108861
# dtype: float64

# %% [markdown]
# ## Removing Skewness using cube root

# %%
df["RI"]=np.cbrt(df["RI"])

# %%
df["Silicon"]=np.cbrt(df["Silicon"])

# %%
df["Magnesium"]=np.cbrt(df["Magnesium"])

# %%
df["Aluminum"]=np.cbrt(df["Aluminum"])

# %%
df["Calcium"]=np.cbrt(df["Calcium"])

# %%
df["Barium"]=np.cbrt(df["Barium"])

# %%
df["Iron"]=np.cbrt(df["Iron"])

# %%
df["Potassium"]=np.cbrt(df["Potassium"])

# %%
df.skew()
# Out:
# RI               0.000000
# Sodium           0.457318
# Magnesium       -1.516649
# Aluminum        -0.845361
# Silicon         -0.813692
# Potassium       -2.079603
# Calcium          1.075629
# Barium           1.748815
# Iron             0.755148
# Type of glass    1.108861
# dtype: float64

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
for i in df.columns:
    if df[i].dtype == object:
        le = LabelEncoder()
        df[i] = le.fit_transform(df[i])

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#            RI  Sodium  Magnesium  Aluminum   Silicon  Potassium   Calcium  \
# 0    1.000572   13.89   1.152952  1.001266  1.054348   0.999988  1.025732
# 1    1.000571   13.53   1.151162  1.001778  1.054395   0.999984  1.025651
# 2    1.000572   13.21   1.156120  1.001048  1.054327   0.999990  1.026348
# 3    1.000572   13.27   1.153662  1.000886  1.054411   0.999990  1.026115
# 4    1.000571   12.79   1.153308  1.001987  1.054391   0.999992  1.026115
# ..        ...     ...        ...       ...       ...        ...       ...
# 208  1.000571   14.14   0.000000  1.004363  1.054327   0.999957  1.027749
# 209  1.000572   14.92   0.000000  1.002836  1.054407   0.000000  1.026623
# 210  1.000575   14.36   0.000000  1.002898  1.054471   0.000000  1.026683
# 211  1.000571   14.38   0.000000  1.002731  1.054505   0.000000  1.026743
# 212  1.000572   14.23   0.000000  1.003018  1.054461   0.000000  1.026950
#
#        Barium      Iron  Type of glass
# 0    0.000000  0.000000              1
# ...

# %%
df.replace({'Type of glass':{(1,2,3,4):1,(5,6,7):2}},inplace=True)

# %% [markdown]
# ### By this we have clearly see that if value of type of class is between 1-4 then it comes under window glasses which is denoted by 1 and rest comes under non window glasses which is denoted by '2'.

# %% [markdown]
# ### SEPERATING FEATURES AND LABEL FOR FURTHER PROCESSES LIKE MODELLING AND FINE TUNING TO INCREASE THE ACCURACY.

# %%
x=df.drop("Type of glass",axis=1)
y=df["Type of glass"]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    2
# 209    2
# 210    2
# 211    2
# 212    2
# Name: Type of glass, Length: 213, dtype: int64

# %%
##Features Scaling using Standard Scaler
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
X=pd.DataFrame(Scaler.fit_transform(x),columns=x.columns)
X

# %% [markdown]
# # multicollinearity treatment

# %%
# Finding the correlation between features so that we can treat multicollinearity issues
plt.figure(figsize=(20,15))
sns.heatmap(x.corr(), linewidth=0.1,fmt=".1g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# ## USING VARIANCE INFLATION FACTOR (VIF) TO REMOVE UNNECESSARY FEATURES

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif["Features"]=X.columns
vif
# Out:
#    VIF values   Features
# 0    6.955323         RI
# 1    2.173381     Sodium
# 2    2.782728  Magnesium
# 3    2.252789   Aluminum
# 4    2.664192    Silicon
# 5    1.977656  Potassium
# 6    5.586221    Calcium
# 7    2.247453     Barium
# 8    1.104944       Iron

# %%
X.drop("RI",axis=1, inplace= True)

# %% [markdown]
# # MODELLING

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y, test_size = 0.25, random_state=41)

# %%
def metric_score(clf, x_train,x_test,y_train,y_test, train=True):
    if train:
        y_pred = clf.predict(x_train)
        print("\n================== Train Result====================")
        print(f"Accuracy Score: {accuracy_score(y_train, y_pred) * 100:.2f}%")
        
        
    elif train==False:
        pred = clf.predict(x_test)
        print("\n================== Test Result====================")
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        
        print('\n \n Test Classification Report \n', classification_report(y_test, pred, digits=2))

# %%
# model initiation
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# call the function and pass dataset to check train and test score
metric_score(clf, x_train,x_test,y_train,y_test, train=True) # This is for training score

metric_score(clf, x_train,x_test,y_train,y_test, train=False) # This is for testing score
# Out:
# ================== Train Result====================
# Accuracy Score: 100.00%
#
# ================== Test Result====================
# Accuracy Score: 94.44%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.98      0.95      0.97        44
#            2       0.82      0.90      0.86        10
#
#     accuracy                           0.94        54
#    macro avg       0.90      0.93      0.91        54
# weighted avg       0.95      0.94      0.95        54

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier

# %%
#Gradient Boosting Classifier

gb = GradientBoostingClassifier()
gb.fit(x_train,y_train)
predgb = gb.predict(x_test)
print('accuracy score is = ',accuracy_score(y_test,predgb))
print(confusion_matrix(y_test,predgb))
print(classification_report(y_test,predgb))
# Out:
# accuracy score is =  0.9444444444444444
# [[42  2]
#  [ 1  9]]
#               precision    recall  f1-score   support
#
#            1       0.98      0.95      0.97        44
#            2       0.82      0.90      0.86        10
#
#     accuracy                           0.94        54
#    macro avg       0.90      0.93      0.91        54
# weighted avg       0.95      0.94      0.95        54

# %%
#random Forest classifier
RFR = RandomForestClassifier()
RFR.fit(x_train,y_train)
predRFC = RFR.predict(x_test)
print('accuracy score is = ',accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# accuracy score is =  0.9074074074074074
# [[40  4]
#  [ 1  9]]
#               precision    recall  f1-score   support
#
#            1       0.98      0.91      0.94        44
#            2       0.69      0.90      0.78        10
#
#     accuracy                           0.91        54
#    macro avg       0.83      0.90      0.86        54
# weighted avg       0.92      0.91      0.91        54

# %% [markdown]
# # DECISION TREE IS OUR BEST MODEL

# %% [markdown]
# # NOW WE ARE USING HYPERPARAMETER TUNING

# %%
# hyperparameter tuning
grid_param ={'criterion': ['gini', 'entropy'], 
            'max_depth': range(10,15),
            'min_samples_leaf': range(2,6),
            'min_samples_split': range(3,8),
            'max_leaf_nodes': range(5,10)}

# %%
grid_search = GridSearchCV(estimator=clf, param_grid=grid_param,cv=5, n_jobs= -1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(10, 15),
#                          'max_leaf_nodes': range(5, 10),
#                          'min_samples_leaf': range(2, 6),
#                          'min_samples_split': range(3, 8)})

# %%
best_parameters = grid_search.best_params_
print(best_parameters)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 9, 'min_samples_leaf': 2, 'min_samples_split': 4}

# %%
# Initiate Decision Tree Classifier with new parameters and train
clf = DecisionTreeClassifier(criterion = 'entropy', min_samples_split =3, max_depth=10, max_leaf_nodes=7, min_samples_leaf=2)

# train the model
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, max_leaf_nodes=7,
#                        min_samples_leaf=2, min_samples_split=3)

# %%
# call the function and pass dataset to check train and test score
metric_score(clf, x_train,x_test,y_train,y_test, train=True) # This is for training score

metric_score(clf, x_train,x_test,y_train,y_test, train=False) # This is for testing score
# Out:
# ================== Train Result====================
# Accuracy Score: 98.74%
#
# ================== Test Result====================
# Accuracy Score: 96.30%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.98      0.98      0.98        44
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.96        54
#    macro avg       0.94      0.94      0.94        54
# weighted avg       0.96      0.96      0.96        54
